# %% [markdown]
# ## tidymodels to sklearn
#
# Sklearn implementation of this tidymodels example: https://www.tidymodels.org/start/case-study/

# %%
import pandas as pd
import numpy as np

np.random.seed(753)
hotels = pd.read_csv('https://tidymodels.org/start/case-study/hotels.csv')

# %%
hotels.shape
# Out:
# (50000, 23)

# %%
hotels.transpose()
# Out:
#                                           0           1             2      \
# hotel                                City_Hotel  City_Hotel  Resort_Hotel
# lead_time                                   217           2            95
# stays_in_weekend_nights                       1           0             2
# stays_in_week_nights                          3           1             5
# adults                                        2           2             2
# children                                   none        none          none
# meal                                         BB          BB            BB
# country                                     DEU         PRT           GBR
# market_segment                    Offline_TA/TO      Direct     Online_TA
# distribution_channel                      TA/TO      Direct         TA/TO
# is_repeated_guest                             0           0             0
# previous_cancellations                        0           0             0
# previous_bookings_not_canceled                0           0             0
# reserved_room_type                            A           D             A
# assigned_room_type                            A           K             A
# booking_changes                               0           0             2
# deposit_type                         No_Deposit  No_Deposit    No_Deposit
# days_in_waiting_list                          0           0             0
# customer_type                   Transient-Party   Transient     Transient
# average_daily_rate                        80.75         170             8
# required_car_parking_spaces                none        none          none
# total_of_special_requests                     1           3             2
# arrival_date                         2016-09-01  2017-08-25    2016-11-19
#
#                                        3             4           5      \
# hotel                           Resort_Hotel  Resort_Hotel  City_Hotel
# lead_time                                143           136          67
# stays_in_weekend_nights                    2             1           2
# stays_in_week_nights                       6             4           2
# adults                                     2             2           2
# children                                none          none        none
# meal                                      HB            HB          SC
# country                                  ROU           PRT         GBR
# market_segment                     Online_TA        Direct   Online_TA
# distribution_channel                   TA/TO        Direct       TA/TO
# is_repeated_guest                          0             0           0
# previous_cancellations                     0             0           0
# previous_bookings_not_canceled             0             0           0
# reserved_room_type                         A             F           A
# assigned_room_type                         A             F           A
# booking_changes                            0             0           0
# deposit_type                      No_Deposit    No_Deposit  No_Deposit
# days_in_waiting_list                       0             0           0
# customer_type                      Transient     Transient   Transient
# average_daily_rate                        81         157.6       49.09
# required_car_parking_spaces             none          none        none
# total_of_special_requests                  1             4           1
# arrival_date                      2016-04-26    2016-12-28  2016-03-13
#
#                                        6           7           8      \
# hotel                           Resort_Hotel  City_Hotel  City_Hotel
# lead_time                                 47          56          80
# stays_in_weekend_nights                    0           0           0
# stays_in_week_nights                       2           3           4
# adults                                     2           0           2
# children                            children    children        none
# meal                                      BB          BB          BB
# country                                  ESP         ESP         FRA
# market_segment                        Direct   Online_TA   Online_TA
# distribution_channel                  Direct       TA/TO       TA/TO
# is_repeated_guest                          0           0           0
# previous_cancellations                     0           0           0
# previous_bookings_not_canceled             0           0           0
# reserved_room_type                         C           B           D
# assigned_room_type                         C           A           D
# booking_changes                            0           0           0
# deposit_type                      No_Deposit  No_Deposit  No_Deposit
# days_in_waiting_list                       0           0           0
# customer_type                      Transient   Transient   Transient
# average_daily_rate                       289       82.44         135
# required_car_parking_spaces             none        none        none
# total_of_special_requests                  1           1           1
# arrival_date                      2017-08-23  2016-12-08  2017-05-02
#
#                                      9      ...          49990          49991  \
# hotel                           City_Hotel  ...   Resort_Hotel   Resort_Hotel
# lead_time                                6  ...            283            197
# stays_in_weekend_nights                  2  ...              2              2
# stays_in_week_nights                     2  ...              8              8
# adults                                   2  ...              2              2
# children                          children  ...           none           none
# meal                                    BB  ...             BB      Undefined
# country                                FRA  ...            GBR            GBR
# market_segment                   Online_TA  ...  Offline_TA/TO  Offline_TA/TO
# distribution_channel                 TA/TO  ...          TA/TO          TA/TO
# is_repeated_guest                        0  ...              0              0
# previous_cancellations                   0  ...              0              0
# previous_bookings_not_canceled           0  ...              0              0
# reserved_room_type                       A  ...              A              D
# assigned_room_type                       A  ...              A              D
# booking_changes                          0  ...              0              1
# deposit_type                    No_Deposit  ...     No_Deposit     No_Deposit
# days_in_waiting_list                     0  ...              0              0
# customer_type                    Transient  ...       Contract      Transient
# average_daily_rate                     180  ...           72.2          114.9
# required_car_parking_spaces           none  ...           none           none
# total_of_special_requests                1  ...              1              0
# arrival_date                    2016-08-07  ...     2017-06-29     2016-06-01
#
#                                           49992       49993       49994  \
# hotel                                City_Hotel  City_Hotel  City_Hotel
# lead_time                                   414         225          73
# stays_in_weekend_nights                       0           2           0
# stays_in_week_nights                          2           4           2
# adults                                        2           2           2
# children                                   none        none        none
# meal                                         HB          BB          SC
# country                                     DEU         BRA         FRA
# market_segment                           Groups   Online_TA   Online_TA
# distribution_channel                      TA/TO       TA/TO       TA/TO
# is_repeated_guest                             0           0           0
# previous_cancellations                        0           0           0
# previous_bookings_not_canceled                0           1           0
# reserved_room_type                            A           A           A
# assigned_room_type                            A           A           A
# booking_changes                               0           0           0
# deposit_type                         No_Deposit  No_Deposit  No_Deposit
# days_in_waiting_list                          0           0           0
# customer_type                   Transient-Party       Group   Transient
# average_daily_rate                        122.4       70.03        79.2
# required_car_parking_spaces                none        none        none
# total_of_special_requests                     1           1           1
# arrival_date                         2017-07-13  2016-10-20  2017-01-27
#
#                                        49995         49996          49997  \
# hotel                           Resort_Hotel  Resort_Hotel     City_Hotel
# lead_time                                172            48            155
# stays_in_weekend_nights                    0             0              0
# stays_in_week_nights                       2             4              4
# adults                                     2             2              2
# children                            children          none           none
# meal                                      BB            FB             BB
# country                                  PRT           PRT            DEU
# market_segment                        Direct        Direct  Offline_TA/TO
# distribution_channel                  Direct        Direct          TA/TO
# is_repeated_guest                          0             0              0
# previous_cancellations                     0             0              0
# previous_bookings_not_canceled             0             0              0
# reserved_room_type                         A             A              A
# assigned_room_type                         A             B              A
# booking_changes                            1             2              0
# deposit_type                      No_Deposit    No_Deposit     No_Deposit
# days_in_waiting_list                       0             0              0
# customer_type                      Transient     Transient      Transient
# average_daily_rate                     73.39           158           82.5
# required_car_parking_spaces             none          none           none
# total_of_special_requests                  1             0              1
# arrival_date                      2016-10-07    2015-09-01     2017-07-26
#
#                                        49998       49999
# hotel                           Resort_Hotel  City_Hotel
# lead_time                                140          12
# stays_in_weekend_nights                    2           2
# stays_in_week_nights                       5           1
# adults                                     2           2
# children                                none        none
# meal                                      HB          BB
# country                                  GBR         DEU
# market_segment                        Direct   Online_TA
# distribution_channel                  Direct       TA/TO
# is_repeated_guest                          0           0
# previous_cancellations                     0           0
# previous_bookings_not_canceled             0           0
# reserved_room_type                         G           A
# assigned_room_type                         G           A
# booking_changes                            0           0
# deposit_type                      No_Deposit  No_Deposit
# days_in_waiting_list                       0           0
# customer_type                      Transient   Transient
# average_daily_rate                       143      171.33
# required_car_parking_spaces             none        none
# total_of_special_requests                  0           1
# arrival_date                      2016-04-28  2016-09-18
#
# [23 rows x 50000 columns]

# %%
hotels \
    .groupby('children') \
    .agg(count=('children', 'count')) \
    .assign(prop = lambda x: x['count'] / x['count'].sum())
# Out:
#           count     prop
# children
# children   4038  0.08076
# none      45962  0.91924

# %%
from sklearn.model_selection import train_test_split

features = hotels.drop('children', axis=1)
outcome = hotels['children']

X_train, X_test, y_train, y_test = train_test_split(
    features, 
    outcome, 
    test_size=0.25, 
    stratify=outcome
)

# %% [markdown]
# https://www.tomasbeuzen.com/post/scikit-learn-gridsearch-pipelines/
#
# https://stackoverflow.com/questions/16437022/how-to-tune-parameters-of-nested-pipelines-by-gridsearchcv-in-scikit-learn

# %%
features
# Out:
#               hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# 0        City_Hotel        217                        1                     3
# 1        City_Hotel          2                        0                     1
# 2      Resort_Hotel         95                        2                     5
# 3      Resort_Hotel        143                        2                     6
# 4      Resort_Hotel        136                        1                     4
# ...             ...        ...                      ...                   ...
# 49995  Resort_Hotel        172                        0                     2
# 49996  Resort_Hotel         48                        0                     4
# 49997    City_Hotel        155                        0                     4
# 49998  Resort_Hotel        140                        2                     5
# 49999    City_Hotel         12                        2                     1
#
#        adults meal country market_segment distribution_channel  \
# 0           2   BB     DEU  Offline_TA/TO                TA/TO
# 1           2   BB     PRT         Direct               Direct
# 2           2   BB     GBR      Online_TA                TA/TO
# 3           2   HB     ROU      Online_TA                TA/TO
# 4           2   HB     PRT         Direct               Direct
# ...       ...  ...     ...            ...                  ...
# 49995       2   BB     PRT         Direct               Direct
# 49996       2   FB     PRT         Direct               Direct
# 49997       2   BB     DEU  Offline_TA/TO                TA/TO
# 49998       2   HB     GBR         Direct               Direct
# 49999       2   BB     DEU      Online_TA                TA/TO
#
#        is_repeated_guest  ...  reserved_room_type  assigned_room_type  \
# 0                      0  ...                   A                   A
# 1                      0  ...                   D                   K
# 2                      0  ...                   A                   A
# 3                      0  ...                   A                   A
# 4                      0  ...                   F                   F
# ...                  ...  ...                 ...                 ...
# 49995                  0  ...                   A                   A
# 49996                  0  ...                   A                   B
# 49997                  0  ...                   A                   A
# 49998                  0  ...                   G                   G
# 49999                  0  ...                   A                   A
#
#       booking_changes deposit_type  days_in_waiting_list    customer_type  \
# 0                   0   No_Deposit                     0  Transient-Party
# 1                   0   No_Deposit                     0        Transient
# 2                   2   No_Deposit                     0        Transient
# 3                   0   No_Deposit                     0        Transient
# 4                   0   No_Deposit                     0        Transient
# ...               ...          ...                   ...              ...
# 49995               1   No_Deposit                     0        Transient
# 49996               2   No_Deposit                     0        Transient
# 49997               0   No_Deposit                     0        Transient
# 49998               0   No_Deposit                     0        Transient
# 49999               0   No_Deposit                     0        Transient
#
#        average_daily_rate required_car_parking_spaces  \
# 0                   80.75                        none
# 1                  170.00                        none
# 2                    8.00                        none
# 3                   81.00                        none
# 4                  157.60                        none
# ...                   ...                         ...
# 49995               73.39                        none
# 49996              158.00                        none
# 49997               82.50                        none
# 49998              143.00                        none
# 49999              171.33                        none
#
#        total_of_special_requests arrival_date
# 0                              1   2016-09-01
# 1                              3   2017-08-25
# 2                              2   2016-11-19
# 3                              1   2016-04-26
# 4                              4   2016-12-28
# ...                          ...          ...
# 49995                          1   2016-10-07
# 49996                          0   2015-09-01
# 49997                          1   2017-07-26
# 49998                          0   2016-04-28
# 49999                          1   2016-09-18
#
# [50000 rows x 22 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

log_preprocess = make_column_transformer(
    (VarianceThreshold(), features.columns),
    (StandardScaler(), features.columns)
)

# %%
from sklearn.model_selection import train_test_split

features = cells.drop('class', axis=1)
outcome = cells['class']

X_train, X_test, y_train, y_test = train_test_split(
    features, 
    outcome, 
    test_size=0.25, 
    stratify=outcome
)

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import make_column_transformer

tree_preprocess = make_column_transformer(
    (FunctionTransformer(), features.drop('case', axis=1).columns)
)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.pipeline import make_pipeline

tree_pipeline = make_pipeline(
    tree_preprocess,
    DecisionTreeClassifier()
)

# %%
param_grid = {
    'decisiontreeclassifier__max_depth': [1, 4, 8, 11, 15],
    'decisiontreeclassifier__ccp_alpha': [0.0000000001, 0.0000000178, 0.00000316, 0.000562, 0.1] 
}

# %%
from sklearn.pipeline import make_pipeline

tree_pipeline = make_pipeline(
    tree_preprocess,
    DecisionTreeClassifier()
)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

tree_scorer = {
    'roc_auc': make_scorer(roc_auc_score, needs_proba=True),
    'accuray': make_scorer(accuracy_score)
}

tree_tuner = GridSearchCV(
    tree_pipeline, param_grid, cv=5, 
    scoring=tree_scorer,
    refit='roc_auc'
)

# %%
tree_res = tree_tuner.fit(X_train, y_train)

# %%
tree_res.best_params_
# Out:
# {'decisiontreeclassifier__ccp_alpha': 1.78e-08,
#  'decisiontreeclassifier__max_depth': 4}

# %%
pd.DataFrame(tree_res.cv_results_) \
    .sort_values('mean_test_roc_auc', ascending=False) \
    .rename(columns={
        'param_decisiontreeclassifier__ccp_alpha': 'cost',
        'param_decisiontreeclassifier__max_depth': 'max_depth'
    }) \
    [[
        'cost', 'max_depth',
        'mean_test_accuray', 'mean_test_roc_auc'
    ]] \
    .head(5)
# Out:
#         cost max_depth  mean_test_accuray  mean_test_roc_auc
# 6   1.78e-08         4           0.797240           0.839899
# 1      1e-10         4           0.796584           0.839053
# 11  3.16e-06         4           0.795257           0.837103
# 16  0.000562         4           0.795917           0.837055
# 0      1e-10         1           0.738461           0.779942

# %%
best_tree = tree_res.best_estimator_.named_steps['decisiontreeclassifier']

# %%
ct = tree_res.best_estimator_.named_steps['columntransformer']

# %%
feature_importances = pd.DataFrame({'name': ct.transformers_[0][2]}) \
    .assign(importance = best_tree.feature_importances_) \
    .sort_values('importance', ascending=False)

# %%
import seaborn as sns
sns.barplot(x='importance', y='name', data=feature_importances.head(10))

# %%
pd.DataFrame.from_records([
    (name, scorer(tree_res.best_estimator_, X_test, y_test)) 
    for name, scorer in tree_scorer.items()
], columns=['metric', 'score'])
# Out:
#     metric     score
# 0  roc_auc  0.824385
# 1  accuray  0.776238
